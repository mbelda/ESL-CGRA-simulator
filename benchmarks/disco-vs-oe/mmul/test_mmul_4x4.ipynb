# %%
from cgra import *
from kernels import *

# %%
kernel_name = "benchmarks/mmul/4x4/mmul"
version = ""

# %%
# Global variables
CGRA_N_ROWS = 4
CGRA_N_COLS = 4
# Adress
first_addr = 20000

# %%
def printAsMatrix(array, rows, cols):
    for i in range(rows):
        print(array[i * cols:(i + 1) * cols])

# %%
# Data
def configMemory(A_data, B_data, C_data, rowsA, colsA, colsB):
    # Clear memory values
    kernel_clear_memory(kernel_name, version=version)
    # Config values
    # ----------------------
    # &B[0][0]          &C[0][1]        &A[0][0]        nRowsBlocksC    
    # nColsBlocksC      &B[0][1]        &C[1][2]        &A[1][0]        
    # &A[2][0]          loopColsA       &B[0][2]        &C[2][3]        
    # &C[3][0]          &A[3][0]        nColsBlocksC    &B[0][3]               
    # ----------------------
    # -4*colsB          colsA           -               -               
    # -                 -4*colsB        colsA           -               
    # -                 -               -4*colsB        colsA           
    # colsA             -               -               -4*colsB             
    nItLoopColsA = colsA
    nColsBlocksC = int(colsB/CGRA_N_ROWS)
    nRowsBlocksC = int(rowsA/CGRA_N_ROWS)
    first_addr_A = first_addr
    first_addr_B = first_addr_A + rowsA*colsA*4
    first_addr_C = first_addr_B + colsA*colsB*4

    config_vals_col0 = [first_addr_B, nColsBlocksC, first_addr_A + 2*colsA*4, first_addr_C + 3*colsB*4, -4*colsB, colsA]
    config_vals_col1 = [first_addr_C + 4, first_addr_B + 4, nItLoopColsA, first_addr_A + 3*colsA*4, colsA, -4*colsB]
    config_vals_col2 = [first_addr_A, first_addr_C + 2*4 + colsB*4, first_addr_B + 2*4, nColsBlocksC, colsA, -4*colsB]
    config_vals_col3 = [nRowsBlocksC, first_addr_A + colsA*4, first_addr_C + 3*4 + 2*colsB*4, first_addr_B + 3*4, colsA, -4*colsB]
    addr_config_loads_col0 = 0
    kernel_add_memory_region(kernel_name, addr_config_loads_col0, config_vals_col0, version=version)
    addr_config_loads_col1 = addr_config_loads_col0 + len(config_vals_col0)*4
    kernel_add_memory_region(kernel_name, addr_config_loads_col1, config_vals_col1, version=version)
    addr_config_loads_col2 = addr_config_loads_col1 + len(config_vals_col1)*4
    kernel_add_memory_region(kernel_name, addr_config_loads_col2, config_vals_col2, version=version)
    addr_config_loads_col3 = addr_config_loads_col2 + len(config_vals_col2)*4
    kernel_add_memory_region(kernel_name, addr_config_loads_col3, config_vals_col3, version=version)
    # Load data
    kernel_add_memory_region(kernel_name, first_addr_A, A_data, version=version)
    kernel_add_memory_region(kernel_name, first_addr_B, B_data, version=version)
    kernel_add_memory_region(kernel_name, first_addr_C, C_data, version=version)
    # Config data address for direct loads
    load_addrs = [addr_config_loads_col0, addr_config_loads_col1, addr_config_loads_col2, addr_config_loads_col3]
    return load_addrs

# %%
def runKernel(load_addrs, max_it=1000):
    # Run kernel
    run(kernel_name, pr=["ROUT","INST"], load_addrs=load_addrs, version=version, limit=max_it)

# %%
def getResult(first_addr_C, end_addr_C, rowsA, colsB):
    result = [0 for _ in range(rowsA*colsB)]
    with open( kernel_name + "/memory_out"+version+".csv", 'r') as f:
        csv_reader = csv.reader(f, delimiter=',')
        for row in csv_reader:
            try:
                if(int(row[0]) >= first_addr_C) and (int(row[0]) < end_addr_C):
                    result[int((int(row[0]) - first_addr_C)/4)] = int(row[1])
            except ValueError:
                print("Error: Values in memory_out CSV file are not integers.")
    return result

# %%
def mmul_cpu(A_data, B_data, C_data, rowsA, colsA, colsB):
    expected_res = [0 for _ in range(rowsA*colsB)]
    for rA in range(rowsA):
        for cB in range(colsB):
            sum = 0
            for cA in range(colsA):
                sum += A_data[rA*colsA + cA] * B_data[cA*colsB + cB]
            expected_res[rA*colsB + cB] = sum 
    return expected_res

# %%
# Test dimensions (4xXx4)
rowsA = 4*5
colsA = 23
colsB = 4*7
A_data = list(range(0, rowsA * colsA))
B_data = [x + 100 for x in range(0, colsA * colsB)]
C_data = [x + 200 for x in range(0, rowsA * colsB)]

A_data_cpy = A_data.copy()
B_data_cpy = B_data.copy()
C_data_cpy = C_data.copy()

#print("A")
#printAsMatrix(A_data, rowsA, colsA)
#print("B")
#printAsMatrix(B_data, colsA, colsB)
load_addrs = configMemory(A_data, B_data, C_data, rowsA, colsA, colsB)

# %%
runKernel(load_addrs, max_it=20000)
# Out:
# Instr =  0 ( 0 )
# [21840, 24420, 20000,    5]    [LWD R2  4, LWD R2  4, LWD R2  4, LWD R2  4]
# [   7, 21844, 24536, 20092]    [LWD R2  4, LWD R2  4, LWD R2  4, LWD R2  4]
# [20184,   23, 21848, 24652]    [LWD R2  4, LWD R2  4, LWD R2  4, LWD R2  4]
# [24752, 20276,    7, 21852]    [LWD R2  4, LWD R2  4, LWD R2  4, LWD R2  4]
# -------
# Instr =  1 ( 1 )
# [-112,   23, 20000,    0]    [LWD R1  4, LWD R1  4, NOP , SADD R1  ZERO  ZERO]
# [   0, -112,   23, 20092]    [SADD R1  ZERO  ZERO, LWD R1  4, LWD R1  4, NOP ]
# [20184,    0, -112,   23]    [NOP , SADD R1  ZERO  ZERO, LWD R1  4, LWD R1  4]
# [  23, 20276,    7, -112]    [LWD R1  4, NOP , NOP , LWD R1  4]
# -------
# Instr =  2 ( 2 )
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# -------
# Instr =  3 ( 3 )
# [ 100,    0,    0,    0]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [   0,  101,    0,   23]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  46,    1,  102,    0]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [   0,   69,    0,  103]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  4 ( 4 )
# [ 100,  101,    0,    0]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  23,  101,  102,   23]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  46,   46,  102,  103]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 100,   69,   69,  103]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  5 ( 5 )
# [   0,    0,  102,  103]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 100,   23,   23,  103]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 100,  101,   46,   46]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  69,  101,  102,   69]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  6 ( 6 )
# [   0,    0,    0,    0]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [2300, 2323, 2346, 2369]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [4600, 4646, 4692, 4738]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [6900, 6969, 7038, 7107]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  7 ( 7 )
# [   0,    0,    0,    0]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [2300, 2323, 2346, 2369]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [4600, 4646, 4692, 4738]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [6900, 6969, 7038, 7107]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  8 ( 8 )
# [21952,    0, 20004,    0]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [2300, 21956, 2346, 20096]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20188,    3, 21960, 4738]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [6900, 20280, 7038, 21964]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  9 ( 3 )
# [ 128,    0,    1,    0]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [2300,  129, 2346,   24]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  47,    2,  130, 4738]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [6900,   70, 7038,  131]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  10 ( 4 )
# [ 128,  129,    1,    1]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  24,  129,  130,   24]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  47,   47,  130,  131]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 128,   70,   70,  131]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  11 ( 5 )
# [   1,    1,  130,  131]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 128,   24,   24,  131]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 128,  129,   47,   47]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  70,  129,  130,   70]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  12 ( 6 )
# [ 128,  129,  130,  131]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [3072, 3096, 3120, 3144]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [6016, 6063, 6110, 6157]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [8960, 9030, 9100, 9170]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  13 ( 7 )
# [ 128,  129,  130,  131]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [5372, 5419, 5466, 5513]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [10616, 10709, 10802, 10895]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [15860, 15999, 16138, 16277]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  14 ( 8 )
# [22064,  129, 20008,  131]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [5372, 22068, 5466, 20100]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20192,    3, 22072, 10895]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [15860, 20284, 16138, 22076]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  15 ( 3 )
# [ 156,  129,    2,  131]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [5372,  157, 5466,   25]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  48,    3,  158, 10895]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [15860,   71, 16138,  159]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  16 ( 4 )
# [ 156,  157,    2,    2]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  25,  157,  158,   25]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  48,   48,  158,  159]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 156,   71,   71,  159]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  17 ( 5 )
# [   2,    2,  158,  159]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 156,   25,   25,  159]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 156,  157,   48,   48]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  71,  157,  158,   71]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  18 ( 6 )
# [ 312,  314,  316,  318]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [3900, 3925, 3950, 3975]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [7488, 7536, 7584, 7632]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [11076, 11147, 11218, 11289]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  19 ( 7 )
# [ 440,  443,  446,  449]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [9272, 9344, 9416, 9488]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [18104, 18245, 18386, 18527]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [26936, 27146, 27356, 27566]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  20 ( 8 )
# [22176,  443, 20012,  449]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [9272, 22180, 9416, 20104]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20196,    3, 22184, 18527]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [26936, 20288, 27356, 22188]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  21 ( 3 )
# [ 184,  443,    3,  449]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [9272,  185, 9416,   26]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  49,    4,  186, 18527]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [26936,   72, 27356,  187]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  22 ( 4 )
# [ 184,  185,    3,    3]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  26,  185,  186,   26]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  49,   49,  186,  187]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 184,   72,   72,  187]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  23 ( 5 )
# [   3,    3,  186,  187]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 184,   26,   26,  187]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 184,  185,   49,   49]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  72,  185,  186,   72]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  24 ( 6 )
# [ 552,  555,  558,  561]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [4784, 4810, 4836, 4862]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [9016, 9065, 9114, 9163]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [13248, 13320, 13392, 13464]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  25 ( 7 )
# [ 992,  998, 1004, 1010]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [14056, 14154, 14252, 14350]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [27120, 27310, 27500, 27690]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [40184, 40466, 40748, 41030]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  26 ( 8 )
# [22288,  998, 20016, 1010]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [14056, 22292, 14252, 20108]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20200,    3, 22296, 27690]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [40184, 20292, 40748, 22300]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  27 ( 3 )
# [ 212,  998,    4, 1010]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [14056,  213, 14252,   27]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  50,    5,  214, 27690]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [40184,   73, 40748,  215]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  28 ( 4 )
# [ 212,  213,    4,    4]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  27,  213,  214,   27]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  50,   50,  214,  215]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 212,   73,   73,  215]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  29 ( 5 )
# [   4,    4,  214,  215]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 212,   27,   27,  215]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 212,  213,   50,   50]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  73,  213,  214,   73]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  30 ( 6 )
# [ 848,  852,  856,  860]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [5724, 5751, 5778, 5805]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [10600, 10650, 10700, 10750]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [15476, 15549, 15622, 15695]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  31 ( 7 )
# [1840, 1850, 1860, 1870]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [19780, 19905, 20030, 20155]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [37720, 37960, 38200, 38440]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [55660, 56015, 56370, 56725]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  32 ( 8 )
# [22400, 1850, 20020, 1870]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [19780, 22404, 20030, 20112]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20204,    3, 22408, 38440]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [55660, 20296, 56370, 22412]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  33 ( 3 )
# [ 240, 1850,    5, 1870]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [19780,  241, 20030,   28]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  51,    6,  242, 38440]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [55660,   74, 56370,  243]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  34 ( 4 )
# [ 240,  241,    5,    5]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  28,  241,  242,   28]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  51,   51,  242,  243]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 240,   74,   74,  243]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  35 ( 5 )
# [   5,    5,  242,  243]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 240,   28,   28,  243]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 240,  241,   51,   51]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  74,  241,  242,   74]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  36 ( 6 )
# [1200, 1205, 1210, 1215]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [6720, 6748, 6776, 6804]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [12240, 12291, 12342, 12393]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [17760, 17834, 17908, 17982]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  37 ( 7 )
# [3040, 3055, 3070, 3085]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [26500, 26653, 26806, 26959]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [49960, 50251, 50542, 50833]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [73420, 73849, 74278, 74707]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  38 ( 8 )
# [22512, 3055, 20024, 3085]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [26500, 22516, 26806, 20116]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20208,    3, 22520, 50833]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [73420, 20300, 74278, 22524]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  39 ( 3 )
# [ 268, 3055,    6, 3085]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [26500,  269, 26806,   29]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  52,    7,  270, 50833]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [73420,   75, 74278,  271]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  40 ( 4 )
# [ 268,  269,    6,    6]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  29,  269,  270,   29]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  52,   52,  270,  271]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 268,   75,   75,  271]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  41 ( 5 )
# [   6,    6,  270,  271]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 268,   29,   29,  271]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 268,  269,   52,   52]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  75,  269,  270,   75]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  42 ( 6 )
# [1608, 1614, 1620, 1626]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [7772, 7801, 7830, 7859]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [13936, 13988, 14040, 14092]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [20100, 20175, 20250, 20325]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  43 ( 7 )
# [4648, 4669, 4690, 4711]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [34272, 34454, 34636, 34818]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [63896, 64239, 64582, 64925]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [93520, 94024, 94528, 95032]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  44 ( 8 )
# [22624, 4669, 20028, 4711]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [34272, 22628, 34636, 20120]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20212,    3, 22632, 64925]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [93520, 20304, 94528, 22636]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  45 ( 3 )
# [ 296, 4669,    7, 4711]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [34272,  297, 34636,   30]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  53,    8,  298, 64925]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [93520,   76, 94528,  299]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  46 ( 4 )
# [ 296,  297,    7,    7]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  30,  297,  298,   30]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  53,   53,  298,  299]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 296,   76,   76,  299]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  47 ( 5 )
# [   7,    7,  298,  299]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 296,   30,   30,  299]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 296,  297,   53,   53]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  76,  297,  298,   76]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  48 ( 6 )
# [2072, 2079, 2086, 2093]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [8880, 8910, 8940, 8970]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [15688, 15741, 15794, 15847]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [22496, 22572, 22648, 22724]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  49 ( 7 )
# [6720, 6748, 6776, 6804]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [43152, 43364, 43576, 43788]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [79584, 79980, 80376, 80772]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [116016, 116596, 117176, 117756]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  50 ( 8 )
# [22736, 6748, 20032, 6804]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [43152, 22740, 43576, 20124]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20216,    3, 22744, 80772]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [116016, 20308, 117176, 22748]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  51 ( 3 )
# [ 324, 6748,    8, 6804]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [43152,  325, 43576,   31]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  54,    9,  326, 80772]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [116016,   77, 117176,  327]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  52 ( 4 )
# [ 324,  325,    8,    8]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  31,  325,  326,   31]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  54,   54,  326,  327]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 324,   77,   77,  327]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  53 ( 5 )
# [   8,    8,  326,  327]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 324,   31,   31,  327]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 324,  325,   54,   54]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  77,  325,  326,   77]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  54 ( 6 )
# [2592, 2600, 2608, 2616]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [10044, 10075, 10106, 10137]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [17496, 17550, 17604, 17658]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [24948, 25025, 25102, 25179]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  55 ( 7 )
# [9312, 9348, 9384, 9420]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [53196, 53439, 53682, 53925]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [97080, 97530, 97980, 98430]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [140964, 141621, 142278, 142935]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  56 ( 8 )
# [22848, 9348, 20036, 9420]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [53196, 22852, 53682, 20128]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20220,    3, 22856, 98430]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [140964, 20312, 142278, 22860]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  57 ( 3 )
# [ 352, 9348,    9, 9420]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [53196,  353, 53682,   32]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  55,   10,  354, 98430]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [140964,   78, 142278,  355]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  58 ( 4 )
# [ 352,  353,    9,    9]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  32,  353,  354,   32]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  55,   55,  354,  355]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 352,   78,   78,  355]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  59 ( 5 )
# [   9,    9,  354,  355]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 352,   32,   32,  355]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 352,  353,   55,   55]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  78,  353,  354,   78]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  60 ( 6 )
# [3168, 3177, 3186, 3195]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [11264, 11296, 11328, 11360]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [19360, 19415, 19470, 19525]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [27456, 27534, 27612, 27690]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  61 ( 7 )
# [12480, 12525, 12570, 12615]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [64460, 64735, 65010, 65285]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [116440, 116945, 117450, 117955]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [168420, 169155, 169890, 170625]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  62 ( 8 )
# [22960, 12525, 20040, 12615]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [64460, 22964, 65010, 20132]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20224,    3, 22968, 117955]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [168420, 20316, 169890, 22972]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  63 ( 3 )
# [ 380, 12525,   10, 12615]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [64460,  381, 65010,   33]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  56,   11,  382, 117955]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [168420,   79, 169890,  383]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  64 ( 4 )
# [ 380,  381,   10,   10]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  33,  381,  382,   33]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  56,   56,  382,  383]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 380,   79,   79,  383]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  65 ( 5 )
# [  10,   10,  382,  383]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 380,   33,   33,  383]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 380,  381,   56,   56]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  79,  381,  382,   79]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  66 ( 6 )
# [3800, 3810, 3820, 3830]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [12540, 12573, 12606, 12639]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [21280, 21336, 21392, 21448]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [30020, 30099, 30178, 30257]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  67 ( 7 )
# [16280, 16335, 16390, 16445]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [77000, 77308, 77616, 77924]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [137720, 138281, 138842, 139403]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [198440, 199254, 200068, 200882]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  68 ( 8 )
# [23072, 16335, 20044, 16445]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [77000, 23076, 77616, 20136]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20228,    3, 23080, 139403]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [198440, 20320, 200068, 23084]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  69 ( 3 )
# [ 408, 16335,   11, 16445]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [77000,  409, 77616,   34]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  57,   12,  410, 139403]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [198440,   80, 200068,  411]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  70 ( 4 )
# [ 408,  409,   11,   11]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  34,  409,  410,   34]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  57,   57,  410,  411]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 408,   80,   80,  411]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  71 ( 5 )
# [  11,   11,  410,  411]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 408,   34,   34,  411]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 408,  409,   57,   57]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  80,  409,  410,   80]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  72 ( 6 )
# [4488, 4499, 4510, 4521]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [13872, 13906, 13940, 13974]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [23256, 23313, 23370, 23427]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [32640, 32720, 32800, 32880]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  73 ( 7 )
# [20768, 20834, 20900, 20966]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [90872, 91214, 91556, 91898]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [160976, 161594, 162212, 162830]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [231080, 231974, 232868, 233762]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  74 ( 8 )
# [23184, 20834, 20048, 20966]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [90872, 23188, 91556, 20140]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20232,    3, 23192, 162830]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [231080, 20324, 232868, 23196]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  75 ( 3 )
# [ 436, 20834,   12, 20966]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [90872,  437, 91556,   35]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  58,   13,  438, 162830]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [231080,   81, 232868,  439]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  76 ( 4 )
# [ 436,  437,   12,   12]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  35,  437,  438,   35]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  58,   58,  438,  439]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 436,   81,   81,  439]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  77 ( 5 )
# [  12,   12,  438,  439]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 436,   35,   35,  439]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 436,  437,   58,   58]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  81,  437,  438,   81]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  78 ( 6 )
# [5232, 5244, 5256, 5268]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [15260, 15295, 15330, 15365]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [25288, 25346, 25404, 25462]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [35316, 35397, 35478, 35559]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  79 ( 7 )
# [26000, 26078, 26156, 26234]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [106132, 106509, 106886, 107263]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [186264, 186940, 187616, 188292]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [266396, 267371, 268346, 269321]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  80 ( 8 )
# [23296, 26078, 20052, 26234]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [106132, 23300, 106886, 20144]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20236,    3, 23304, 188292]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [266396, 20328, 268346, 23308]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  81 ( 3 )
# [ 464, 26078,   13, 26234]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [106132,  465, 106886,   36]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  59,   14,  466, 188292]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [266396,   82, 268346,  467]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  82 ( 4 )
# [ 464,  465,   13,   13]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  36,  465,  466,   36]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  59,   59,  466,  467]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 464,   82,   82,  467]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  83 ( 5 )
# [  13,   13,  466,  467]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 464,   36,   36,  467]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 464,  465,   59,   59]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  82,  465,  466,   82]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  84 ( 6 )
# [6032, 6045, 6058, 6071]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [16704, 16740, 16776, 16812]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [27376, 27435, 27494, 27553]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [38048, 38130, 38212, 38294]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  85 ( 7 )
# [32032, 32123, 32214, 32305]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [122836, 123249, 123662, 124075]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [213640, 214375, 215110, 215845]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [304444, 305501, 306558, 307615]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  86 ( 8 )
# [23408, 32123, 20056, 32305]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [122836, 23412, 123662, 20148]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20240,    3, 23416, 215845]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [304444, 20332, 306558, 23420]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  87 ( 3 )
# [ 492, 32123,   14, 32305]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [122836,  493, 123662,   37]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  60,   15,  494, 215845]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [304444,   83, 306558,  495]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  88 ( 4 )
# [ 492,  493,   14,   14]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  37,  493,  494,   37]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  60,   60,  494,  495]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 492,   83,   83,  495]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  89 ( 5 )
# [  14,   14,  494,  495]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 492,   37,   37,  495]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 492,  493,   60,   60]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  83,  493,  494,   83]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  90 ( 6 )
# [6888, 6902, 6916, 6930]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [18204, 18241, 18278, 18315]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [29520, 29580, 29640, 29700]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [40836, 40919, 41002, 41085]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  91 ( 7 )
# [38920, 39025, 39130, 39235]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [141040, 141490, 141940, 142390]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [243160, 243955, 244750, 245545]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [345280, 346420, 347560, 348700]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  92 ( 8 )
# [23520, 39025, 20060, 39235]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [141040, 23524, 141940, 20152]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20244,    3, 23528, 245545]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [345280, 20336, 347560, 23532]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  93 ( 3 )
# [ 520, 39025,   15, 39235]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [141040,  521, 141940,   38]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  61,   16,  522, 245545]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [345280,   84, 347560,  523]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  94 ( 4 )
# [ 520,  521,   15,   15]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  38,  521,  522,   38]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  61,   61,  522,  523]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 520,   84,   84,  523]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  95 ( 5 )
# [  15,   15,  522,  523]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 520,   38,   38,  523]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 520,  521,   61,   61]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  84,  521,  522,   84]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  96 ( 6 )
# [7800, 7815, 7830, 7845]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [19760, 19798, 19836, 19874]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [31720, 31781, 31842, 31903]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [43680, 43764, 43848, 43932]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  97 ( 7 )
# [46720, 46840, 46960, 47080]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [160800, 161288, 161776, 162264]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [274880, 275736, 276592, 277448]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [388960, 390184, 391408, 392632]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  98 ( 8 )
# [23632, 46840, 20064, 47080]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [160800, 23636, 161776, 20156]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20248,    3, 23640, 277448]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [388960, 20340, 391408, 23644]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  99 ( 3 )
# [ 548, 46840,   16, 47080]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [160800,  549, 161776,   39]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  62,   17,  550, 277448]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [388960,   85, 391408,  551]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  100 ( 4 )
# [ 548,  549,   16,   16]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  39,  549,  550,   39]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  62,   62,  550,  551]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 548,   85,   85,  551]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  101 ( 5 )
# [  16,   16,  550,  551]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 548,   39,   39,  551]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 548,  549,   62,   62]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  85,  549,  550,   85]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  102 ( 6 )
# [8768, 8784, 8800, 8816]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [21372, 21411, 21450, 21489]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [33976, 34038, 34100, 34162]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [46580, 46665, 46750, 46835]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  103 ( 7 )
# [55488, 55624, 55760, 55896]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [182172, 182699, 183226, 183753]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [308856, 309774, 310692, 311610]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [435540, 436849, 438158, 439467]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  104 ( 8 )
# [23744, 55624, 20068, 55896]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [182172, 23748, 183226, 20160]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20252,    3, 23752, 311610]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [435540, 20344, 438158, 23756]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  105 ( 3 )
# [ 576, 55624,   17, 55896]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [182172,  577, 183226,   40]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  63,   18,  578, 311610]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [435540,   86, 438158,  579]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  106 ( 4 )
# [ 576,  577,   17,   17]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  40,  577,  578,   40]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  63,   63,  578,  579]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 576,   86,   86,  579]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  107 ( 5 )
# [  17,   17,  578,  579]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 576,   40,   40,  579]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 576,  577,   63,   63]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  86,  577,  578,   86]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  108 ( 6 )
# [9792, 9809, 9826, 9843]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [23040, 23080, 23120, 23160]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [36288, 36351, 36414, 36477]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [49536, 49622, 49708, 49794]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  109 ( 7 )
# [65280, 65433, 65586, 65739]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [205212, 205779, 206346, 206913]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [345144, 346125, 347106, 348087]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [485076, 486471, 487866, 489261]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  110 ( 8 )
# [23856, 65433, 20072, 65739]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [205212, 23860, 206346, 20164]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20256,    3, 23864, 348087]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [485076, 20348, 487866, 23868]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  111 ( 3 )
# [ 604, 65433,   18, 65739]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [205212,  605, 206346,   41]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  64,   19,  606, 348087]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [485076,   87, 487866,  607]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  112 ( 4 )
# [ 604,  605,   18,   18]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  41,  605,  606,   41]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  64,   64,  606,  607]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 604,   87,   87,  607]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  113 ( 5 )
# [  18,   18,  606,  607]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 604,   41,   41,  607]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# ...
# [2873560, 2881160, 2888760, 2896360]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3037872, 3045909, 3053946, 3061983]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3202184, 3210658, 3219132, 3227606]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  5092 ( 8 )
# [24064, 2716411, 21548, 2730737]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [2873560, 24068, 2888760, 21640]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [21732,    3, 24072, 3061983]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [3202184, 21824, 3219132, 24076]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  5093 ( 3 )
# [ 656, 2716411,  387, 2730737]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [2873560,  657, 2888760,  410]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [ 433,   20,  658, 3061983]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [3202184,  456, 3219132,  659]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  5094 ( 4 )
# [ 656,  657,  387,  387]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [ 410,  657,  658,  410]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [ 433,  433,  658,  659]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 656,  456,  456,  659]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  5095 ( 5 )
# [ 387,  387,  658,  659]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 656,  410,  410,  659]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 656,  657,  433,  433]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 456,  657,  658,  456]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  5096 ( 6 )
# [253872, 254259, 254646, 255033]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [268960, 269370, 269780, 270190]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [284048, 284481, 284914, 285347]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [299136, 299592, 300048, 300504]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  5097 ( 7 )
# [2963120, 2970670, 2978220, 2985770]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3142520, 3150530, 3158540, 3166550]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3321920, 3330390, 3338860, 3347330]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3501320, 3510250, 3519180, 3528110]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  5098 ( 8 )
# [24176, 2970670, 21552, 2985770]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [3142520, 24180, 3158540, 21644]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [21736,    3, 24184, 3347330]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [3501320, 21828, 3519180, 24188]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  5099 ( 3 )
# [ 684, 2970670,  388, 2985770]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [3142520,  685, 3158540,  411]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [ 434,   21,  686, 3347330]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [3501320,  457, 3519180,  687]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  5100 ( 4 )
# [ 684,  685,  388,  388]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [ 411,  685,  686,  411]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [ 434,  434,  686,  687]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 684,  457,  457,  687]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  5101 ( 5 )
# [ 388,  388,  686,  687]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 684,  411,  411,  687]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 684,  685,  434,  434]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 457,  685,  686,  457]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  5102 ( 6 )
# [265392, 265780, 266168, 266556]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [281124, 281535, 281946, 282357]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [296856, 297290, 297724, 298158]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [312588, 313045, 313502, 313959]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  5103 ( 7 )
# [3228512, 3236450, 3244388, 3252326]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3423644, 3432065, 3440486, 3448907]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3618776, 3627680, 3636584, 3645488]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3813908, 3823295, 3832682, 3842069]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  5104 ( 8 )
# [24288, 3236450, 21556, 3252326]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [3423644, 24292, 3440486, 21648]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [21740,    3, 24296, 3645488]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [3813908, 21832, 3832682, 24300]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  5105 ( 3 )
# [ 712, 3236450,  389, 3252326]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [3423644,  713, 3440486,  412]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [ 435,   22,  714, 3645488]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [3813908,  458, 3832682,  715]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  5106 ( 4 )
# [ 712,  713,  389,  389]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [ 412,  713,  714,  412]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [ 435,  435,  714,  715]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 712,  458,  458,  715]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  5107 ( 5 )
# [ 389,  389,  714,  715]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 712,  412,  412,  715]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 712,  713,  435,  435]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 458,  713,  714,  458]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  5108 ( 6 )
# [276968, 277357, 277746, 278135]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [293344, 293756, 294168, 294580]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [309720, 310155, 310590, 311025]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [326096, 326554, 327012, 327470]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  5109 ( 7 )
# [3505480, 3513807, 3522134, 3530461]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3716988, 3725821, 3734654, 3743487]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3928496, 3937835, 3947174, 3956513]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [4140004, 4149849, 4159694, 4169539]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  5110 ( 8 )
# [24400, 3513807, 21560, 3530461]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [3716988, 24404, 3734654, 21652]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [21744,    3, 24408, 3956513]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [4140004, 21836, 4159694, 24412]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  5111 ( 3 )
# [ 740, 3513807,  390, 3530461]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [3716988,  741, 3734654,  413]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [ 436,   23,  742, 3956513]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [4140004,  459, 4159694,  743]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  5112 ( 4 )
# [ 740,  741,  390,  390]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [ 413,  741,  742,  413]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [ 436,  436,  742,  743]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 740,  459,  459,  743]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  5113 ( 5 )
# [ 390,  390,  742,  743]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 740,  413,  413,  743]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 740,  741,  436,  436]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 459,  741,  742,  459]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  5114 ( 6 )
# [288600, 288990, 289380, 289770]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [305620, 306033, 306446, 306859]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [322640, 323076, 323512, 323948]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [339660, 340119, 340578, 341037]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  5115 ( 7 )
# [3794080, 3802797, 3811514, 3820231]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [4022608, 4031854, 4041100, 4050346]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [4251136, 4260911, 4270686, 4280461]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [4479664, 4489968, 4500272, 4510576]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  5116 ( 8 )
# [24512, 3802797, 21564, 3820231]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [4022608, 24516, 4041100, 21656]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [21748,    3, 24520, 4280461]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [4479664, 21840, 4500272, 24524]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  5117 ( 9 )
# [24512, 26308, 21564, 3820231]    [NOP , SADD ROUT  ZERO  R2, NOP , NOP ]
# [   7, 24516, 26424, 21656]    [SADD R1  R1  1, NOP , SADD ROUT  ZERO  R2, NOP ]
# [21748,    3, 24520, 26540]    [NOP , NOP , NOP , SADD ROUT  ZERO  R2]
# [26640, 21840, 4500272, 24524]    [SADD ROUT  ZERO  R2, NOP , NOP , NOP ]
# -------
# Instr =  5118 ( 10 )
# [26304, 26324, 26312, 3820231]    [SADD ROUT  RCR  -4, SADD R2  R2  16, SADD ROUT  RCL  4, NOP ]
# [   7, 26420, 26440, 26428]    [NOP , SADD ROUT  RCR  -4, SADD R2  R2  16, SADD ROUT  RCL  4]
# [26528,    3, 26536, 26556]    [SADD ROUT  RCL  -12, NOP , SADD ROUT  RCR  -4, SADD R2  R2  16]
# [26656, 26644, 4500272, 26652]    [SADD R2  R2  16, SADD ROUT  RCL  4, NOP , SADD ROUT  RCR  12]
# -------
# Instr =  5119 ( 11 )
# [26304, 26308, 26312, 26316]    [NOP , SADD ROUT  R2  -16, NOP , SADD ROUT  RCL  4]
# [26416, 26420, 26424, 26428]    [SADD ROUT  RCR  -4, NOP , SADD ROUT  R2  -16, NOP ]
# [26528, 26532, 26536, 26540]    [NOP , SADD ROUT  RCR  -4, NOP , SADD ROUT  R2  -16]
# [26640, 26644, 26648, 26652]    [SADD ROUT  R2  -16, NOP , SADD ROUT  RCR  -4, NOP ]
# -------
# Instr =  5120 ( 12 )
# [26304, 26308, 26312, 26316]    [SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT]
# [26416, 26420, 26424, 26428]    [SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT]
# [26528, 26532, 26536, 26540]    [SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT]
# [26640, 26644, 26648, 26652]    [SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT]
# -------
# Instr =  5121 ( 13 )
# [24528,   23, 26312, 26316]    [SADD R2  R2  16, SADD ROUT  ZERO  R1, NOP , NOP ]
# [26416, 24532,   23, 26428]    [NOP , SADD R2  R2  16, SADD ROUT  ZERO  R1, NOP ]
# [26528, 26532, 24536,   23]    [NOP , NOP , SADD R2  R2  16, SADD ROUT  ZERO  R1]
# [  23, 26644, 26648, 24540]    [SADD ROUT  ZERO  R1, NOP , NOP , SADD R2  R2  16]
# -------
# Instr =  5122 ( 14 )
# [-2576,   23,  -92, 26316]    [SMUL ROUT  RCR  R1, NOP , SMUL ROUT  RCL  -4, NOP ]
# [26416, -2576,   23,  -92]    [NOP , SMUL ROUT  RCR  R1, NOP , SMUL ROUT  RCL  -4]
# [ -92,    0, -2576,   23]    [SMUL ROUT  RCL  -4, SADD R1  ZERO  ZERO, SMUL ROUT  RCR  R1, NOP ]
# [  23,  -92, 26648, -2576]    [NOP , SMUL ROUT  RCL  -4, NOP , SMUL ROUT  RCR  R1]
# -------
# Instr =  5123 ( 15 )
# [21952,   23, 21472, 26316]    [SADD R2  R2  ROUT, NOP , SADD R2  R2  ROUT, NOP ]
# [   0, 21956,   23, 21564]    [SADD R3  ZERO  ZERO, SADD R2  R2  ROUT, NOP , SADD R2  R2  ROUT]
# [21656,    0, 21960,   23]    [SADD R2  R2  ROUT, NOP , SADD R2  R2  ROUT, NOP ]
# [  23, 21748, 26648, 21964]    [NOP , SADD R2  R2  ROUT, NOP , SADD R2  R2  ROUT]
# -------
# Instr =  5124 ( 16 )
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   3,    0,    0,    0]    [BNE R1  R2  3, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# -------
# Instr =  5125 ( 17 )
# [ 448,  368,    0,    5]    [SMUL ROUT  R1  -4, SMUL ROUT  R1  16, NOP , SADD R1  R1  1]
# [-112,  448,  368,    0]    [SMUL ROUT  R2  -16, SMUL ROUT  R1  -4, SMUL ROUT  R1  16, NOP ]
# [   0,    0,  448,  368]    [NOP , NOP , SMUL ROUT  R1  -4, SMUL ROUT  R1  16]
# [ 368,    0, -112,  448]    [SMUL ROUT  R1  16, NOP , SMUL ROUT  R2  -16, SMUL ROUT  R1  -4]
# -------
# Instr =  5126 ( 18 )
# [-112, 26772, 21840,    5]    [SADD ROUT  ZERO  RCB, SADD R2  R2  RCL, SADD R2  R2  RCL, NOP ]
# [   0, -112, 26888, 21932]    [SADD R1  ZERO  ZERO, SADD ROUT  ZERO  RCL, SADD R2  R2  RCL, SADD R2  R2  RCL]
# [22024,    0, -112, 27004]    [SADD R2  R2  RCL, NOP , SADD ROUT  ZERO  RCB, SADD R2  R2  RCL]
# [27104, 22116, -112, -112]    [SADD R2  R2  RCL, SADD R2  R2  RCL, NOP , SADD ROUT  ZERO  RCL]
# -------
# Instr =  5127 ( 19 )
# [21840, 26660, 21840,    3]    [SADD R2  R2  ROUT, SADD R2  R2  RCL, NOP , BNE R1  R2  3]
# [   0, 21844, 26776, 21932]    [NOP , SADD R2  R2  ROUT, SADD R2  R2  RCL, NOP ]
# [22024,    0, 21848, 26892]    [NOP , NOP , SADD R2  R2  ROUT, SADD R2  R2  RCL]
# [26992, 22116, -112, 21852]    [SADD R2  R2  RCL, NOP , NOP , SADD R2  R2  ROUT]
# -------
# Instr =  5128 ( 20 )
# [21840, 26660, 21840,    3]    [EXIT, NOP , NOP , NOP ]
# [   0, 21844, 26776, 21932]    [NOP , NOP , NOP , NOP ]
# [22024,    0, 21848, 26892]    [NOP , NOP , NOP , NOP ]
# [26992, 22116, -112, 21852]    [NOP , NOP , NOP , NOP ]
#
#
# END

# %%
# Get result from CGRA
first_addr_C = first_addr + rowsA*colsA*4 + colsA*colsB*4
result = getResult(first_addr_C, first_addr_C + rowsA*colsB*4, rowsA, colsB)
# Process estra rows/cols
if rowsA%CGRA_N_COLS != 0:
    for rA in range(rowsA - rowsA%CGRA_N_COLS, rowsA):
        for cB in range(colsB):
            sum = 0
            for k in range(colsA):
                sum += A_data[rA*colsA+k]*B_data[k*colsB+cB]
            result[rA*colsB+cB] = sum 
if colsB%CGRA_N_COLS != 0:
    for cB in range(colsB - colsB%CGRA_N_COLS, colsB):
        for rA in range(rowsA - rowsA%CGRA_N_COLS):
            sum = 0
            for k in range(colsA):
                sum += A_data[rA*colsA+k]*B_data[k*colsB+cB]
            result[rA*colsB+cB] = sum

# Get cpu output
expected_res = mmul_cpu(A_data_cpy, B_data_cpy, C_data_cpy, rowsA, colsA, colsB)

# Check result correctness
errors = 0
for i in range(len(expected_res)):
    if expected_res[i] != result[i]:
        errors += 1
if errors > 0:
    print("Err: " + str(errors))
    print("Expected: ")
    printAsMatrix(expected_res, rowsA, colsB)
    print("CGRA: ")
    printAsMatrix(result, rowsA, colsB)
else:
    print("OK")
# Out:
# OK
