# %%
from cgra import *
from kernels import *
from sat_to_csv import *

# %%
kernel_name = "gemm"
version = "_meth_compact"

# %%
# Global variables
CGRA_N_ROWS = 4
CGRA_N_COLS = 4
# Adress
first_addr = 20000

# %%
def printAsMatrix(array, rows, cols):
    for i in range(rows):
        print(array[i * cols:(i + 1) * cols])

# %%
# Data
def configMemory(A_data, B_data, C_data, rowsA, colsA, colsB, alpha, beta):
    # Clear memory values
    kernel_clear_memory(kernel_name, version=version)
    # Config values
    # ----------------------
    # &B[0][0]          &C[0][1]        &A[0][0]        nRowsBlocksC
    # nColsBlocksC      &B[0][1]        &C[1][2]        &A[1][0]
    # &A[2][0]          loopColsA       &B[0][2]        &C[2][3]
    # &C[3][0]          &A[3][0]        nColsBlocksC    &B[0][3]
    # ----------------------
    # -4*colsB          colsA           alpha           -
    # -                 -4*colsB        colsA           alpha
    # beta              -               -4*colsB        colsA
    # colsA             beta            -               -4*colsB
    nItLoopColsA = colsA
    nColsBlocksC = int(colsB/CGRA_N_ROWS)
    nRowsBlocksC = int(rowsA/CGRA_N_ROWS)
    first_addr_A = first_addr
    first_addr_B = first_addr_A + rowsA*colsA*4
    first_addr_C = first_addr_B + colsA*colsB*4
    config_vals_col0 = [first_addr_B, nColsBlocksC, first_addr_A + 2*colsA*4, first_addr_C + 3*colsB*4, -4*colsB, beta, colsA]
    config_vals_col1 = [first_addr_C + 4, first_addr_B + 4, nItLoopColsA, first_addr_A + 3*colsA*4, colsA, -4*colsB, beta]
    config_vals_col2 = [first_addr_A, first_addr_C + 2*4 + colsB*4, first_addr_B + 2*4, nColsBlocksC, alpha, colsA, -4*colsB]
    config_vals_col3 = [nRowsBlocksC, first_addr_A + colsA*4, first_addr_C + 3*4 + 2*colsB*4, first_addr_B + 3*4, alpha, colsA, -4*colsB]
    addr_config_loads_col0 = 0
    kernel_add_memory_region(kernel_name, addr_config_loads_col0, config_vals_col0, version=version)
    addr_config_loads_col1 = addr_config_loads_col0 + len(config_vals_col0)*4
    kernel_add_memory_region(kernel_name, addr_config_loads_col1, config_vals_col1, version=version)
    addr_config_loads_col2 = addr_config_loads_col1 + len(config_vals_col1)*4
    kernel_add_memory_region(kernel_name, addr_config_loads_col2, config_vals_col2, version=version)
    addr_config_loads_col3 = addr_config_loads_col2 + len(config_vals_col2)*4
    kernel_add_memory_region(kernel_name, addr_config_loads_col3, config_vals_col3, version=version)
    # Load data
    kernel_add_memory_region(kernel_name, first_addr_A, A_data, version=version)
    kernel_add_memory_region(kernel_name, first_addr_B, B_data, version=version)
    kernel_add_memory_region(kernel_name, first_addr_C, C_data, version=version)
    # Config data address for direct loads
    load_addrs = [addr_config_loads_col0, addr_config_loads_col1, addr_config_loads_col2, addr_config_loads_col3]
    return load_addrs

# %%
def runKernel(load_addrs, max_it=1000):
    # Run kernel
    run(kernel_name, pr=["ROUT","INST"], load_addrs=load_addrs, version=version, limit=max_it)

# %%
def getResult(first_addr_C, end_addr_C, rowsA, colsB):
    result = [0 for _ in range(rowsA*colsB)]
    with open( kernel_name + "/memory_out"+version+".csv", 'r') as f:
        csv_reader = csv.reader(f, delimiter=',')
        for row in csv_reader:
            try:
                if(int(row[0]) >= first_addr_C) and (int(row[0]) < end_addr_C):
                    result[int((int(row[0]) - first_addr_C)/4)] = int(row[1])
            except ValueError:
                print("Error: Values in memory_out CSV file are not integers.")
    return result

# %%
def gemm_cpu(A_data, B_data, C_data, rowsA, colsA, colsB, alpha, beta):
    expected_res = [0 for _ in range(rowsA*colsB)]
    for rA in range(rowsA):
        for cB in range(colsB):
            sum = 0
            for cA in range(colsA):
                sum += A_data[rA*colsA + cA] * B_data[cA*colsB + cB]
            expected_res[rA*colsB + cB] = alpha * sum + beta * C_data[rA*colsB + cB]
    return expected_res

# %%
# Test dimensions (4xXx4)
rowsA = 20
colsA = 30
colsB = 25
A_data = list(range(0, rowsA * colsA))
B_data = [x + 100 for x in range(0, colsA * colsB)]
C_data = [x + 200 for x in range(0, rowsA * colsB)]

A_data_cpy = A_data.copy()
B_data_cpy = B_data.copy()
C_data_cpy = C_data.copy()

alpha = 125 
beta = 14
#print("A")
#printAsMatrix(A_data, rowsA, colsA)
#print("B")
#printAsMatrix(B_data, colsA, colsB)
load_addrs = configMemory(A_data, B_data, C_data, rowsA, colsA, colsB, alpha, beta)

# %%
runKernel(load_addrs, max_it=200000)
# Out:
# Instr =  0 ( 0 )
# [22400, 25404, 20000,    5]    [LWD R2  4, LWD R2  4, LWD R2  4, LWD R2  4]
# [   6, 22404, 25508, 20120]    [LWD R2  4, LWD R2  4, LWD R2  4, LWD R2  4]
# [20240,   30, 22408, 25612]    [LWD R2  4, LWD R2  4, LWD R2  4, LWD R2  4]
# [25700, 20360,    6, 22412]    [LWD R2  4, LWD R2  4, LWD R2  4, LWD R2  4]
# -------
# Instr =  1 ( 1 )
# [-100,   30,  125,    0]    [LWD R1  4, LWD R1  4, LWD R1  4, SADD R1  ZERO  ZERO]
# [   0, -100,   30,  125]    [SADD R1  ZERO  ZERO, LWD R1  4, LWD R1  4, LWD R1  4]
# [  14,    0, -100,   30]    [LWD R1  4, SADD R1  ZERO  ZERO, LWD R1  4, LWD R1  4]
# [  30,   14,    6, -100]    [LWD R1  4, LWD R1  4, NOP , LWD R1  4]
# -------
# Instr =  2 ( 2 )
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# [   0,    0,    0,    0]    [SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO, SADD R3  ZERO  ZERO]
# -------
# Instr =  3 ( 3 )
# [ 100,    0,    0,    0]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [   0,  101,    0,   30]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  60,    1,  102,    0]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [   0,   90,    0,  103]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  4 ( 4 )
# [ 100,  101,    0,    0]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  30,  101,  102,   30]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  60,   60,  102,  103]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 100,   90,   90,  103]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  5 ( 5 )
# [   0,    0,  102,  103]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 100,   30,   30,  103]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 100,  101,   60,   60]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  90,  101,  102,   90]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  6 ( 6 )
# [   0,    0,    0,    0]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [3000, 3030, 3060, 3090]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [6000, 6060, 6120, 6180]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [9000, 9090, 9180, 9270]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  7 ( 7 )
# [   0,    0,    0,    0]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [3000, 3030, 3060, 3090]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [6000, 6060, 6120, 6180]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [9000, 9090, 9180, 9270]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  8 ( 8 )
# [22500,    0, 20004,    0]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [3000, 22504, 3060, 20124]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20244,    3, 22508, 6180]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [9000, 20364, 9180, 22512]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  9 ( 3 )
# [ 125,    0,    1,    0]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [3000,  126, 3060,   31]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  61,    2,  127, 6180]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [9000,   91, 9180,  128]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  10 ( 4 )
# [ 125,  126,    1,    1]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  31,  126,  127,   31]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  61,   61,  127,  128]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 125,   91,   91,  128]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  11 ( 5 )
# [   1,    1,  127,  128]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 125,   31,   31,  128]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 125,  126,   61,   61]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  91,  126,  127,   91]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  12 ( 6 )
# [ 125,  126,  127,  128]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [3875, 3906, 3937, 3968]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [7625, 7686, 7747, 7808]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [11375, 11466, 11557, 11648]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  13 ( 7 )
# [ 125,  126,  127,  128]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [6875, 6936, 6997, 7058]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [13625, 13746, 13867, 13988]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [20375, 20556, 20737, 20918]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  14 ( 8 )
# [22600,  126, 20008,  128]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [6875, 22604, 6997, 20128]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20248,    3, 22608, 13988]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [20375, 20368, 20737, 22612]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  15 ( 3 )
# [ 150,  126,    2,  128]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [6875,  151, 6997,   32]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  62,    3,  152, 13988]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [20375,   92, 20737,  153]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  16 ( 4 )
# [ 150,  151,    2,    2]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  32,  151,  152,   32]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  62,   62,  152,  153]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 150,   92,   92,  153]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  17 ( 5 )
# [   2,    2,  152,  153]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 150,   32,   32,  153]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 150,  151,   62,   62]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  92,  151,  152,   92]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  18 ( 6 )
# [ 300,  302,  304,  306]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [4800, 4832, 4864, 4896]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [9300, 9362, 9424, 9486]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [13800, 13892, 13984, 14076]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  19 ( 7 )
# [ 425,  428,  431,  434]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [11675, 11768, 11861, 11954]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [22925, 23108, 23291, 23474]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [34175, 34448, 34721, 34994]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  20 ( 8 )
# [22700,  428, 20012,  434]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [11675, 22704, 11861, 20132]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20252,    3, 22708, 23474]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [34175, 20372, 34721, 22712]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  21 ( 3 )
# [ 175,  428,    3,  434]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [11675,  176, 11861,   33]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  63,    4,  177, 23474]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [34175,   93, 34721,  178]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  22 ( 4 )
# [ 175,  176,    3,    3]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  33,  176,  177,   33]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  63,   63,  177,  178]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 175,   93,   93,  178]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  23 ( 5 )
# [   3,    3,  177,  178]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 175,   33,   33,  178]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 175,  176,   63,   63]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  93,  176,  177,   93]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  24 ( 6 )
# [ 525,  528,  531,  534]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [5775, 5808, 5841, 5874]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [11025, 11088, 11151, 11214]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [16275, 16368, 16461, 16554]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  25 ( 7 )
# [ 950,  956,  962,  968]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [17450, 17576, 17702, 17828]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [33950, 34196, 34442, 34688]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [50450, 50816, 51182, 51548]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  26 ( 8 )
# [22800,  956, 20016,  968]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [17450, 22804, 17702, 20136]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20256,    3, 22808, 34688]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [50450, 20376, 51182, 22812]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  27 ( 3 )
# [ 200,  956,    4,  968]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [17450,  201, 17702,   34]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  64,    5,  202, 34688]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [50450,   94, 51182,  203]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  28 ( 4 )
# [ 200,  201,    4,    4]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  34,  201,  202,   34]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  64,   64,  202,  203]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 200,   94,   94,  203]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  29 ( 5 )
# [   4,    4,  202,  203]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 200,   34,   34,  203]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 200,  201,   64,   64]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  94,  201,  202,   94]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  30 ( 6 )
# [ 800,  804,  808,  812]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [6800, 6834, 6868, 6902]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [12800, 12864, 12928, 12992]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [18800, 18894, 18988, 19082]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  31 ( 7 )
# [1750, 1760, 1770, 1780]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [24250, 24410, 24570, 24730]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [46750, 47060, 47370, 47680]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [69250, 69710, 70170, 70630]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  32 ( 8 )
# [22900, 1760, 20020, 1780]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [24250, 22904, 24570, 20140]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20260,    3, 22908, 47680]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [69250, 20380, 70170, 22912]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  33 ( 3 )
# [ 225, 1760,    5, 1780]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [24250,  226, 24570,   35]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  65,    6,  227, 47680]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [69250,   95, 70170,  228]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  34 ( 4 )
# [ 225,  226,    5,    5]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  35,  226,  227,   35]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  65,   65,  227,  228]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 225,   95,   95,  228]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  35 ( 5 )
# [   5,    5,  227,  228]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 225,   35,   35,  228]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 225,  226,   65,   65]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  95,  226,  227,   95]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  36 ( 6 )
# [1125, 1130, 1135, 1140]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [7875, 7910, 7945, 7980]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [14625, 14690, 14755, 14820]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [21375, 21470, 21565, 21660]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  37 ( 7 )
# [2875, 2890, 2905, 2920]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [32125, 32320, 32515, 32710]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [61375, 61750, 62125, 62500]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [90625, 91180, 91735, 92290]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  38 ( 8 )
# [23000, 2890, 20024, 2920]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [32125, 23004, 32515, 20144]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20264,    3, 23008, 62500]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [90625, 20384, 91735, 23012]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  39 ( 3 )
# [ 250, 2890,    6, 2920]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [32125,  251, 32515,   36]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  66,    7,  252, 62500]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [90625,   96, 91735,  253]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  40 ( 4 )
# [ 250,  251,    6,    6]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  36,  251,  252,   36]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  66,   66,  252,  253]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 250,   96,   96,  253]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  41 ( 5 )
# [   6,    6,  252,  253]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 250,   36,   36,  253]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 250,  251,   66,   66]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  96,  251,  252,   96]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  42 ( 6 )
# [1500, 1506, 1512, 1518]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [9000, 9036, 9072, 9108]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [16500, 16566, 16632, 16698]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [24000, 24096, 24192, 24288]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  43 ( 7 )
# [4375, 4396, 4417, 4438]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [41125, 41356, 41587, 41818]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [77875, 78316, 78757, 79198]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [114625, 115276, 115927, 116578]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  44 ( 8 )
# [23100, 4396, 20028, 4438]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [41125, 23104, 41587, 20148]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20268,    3, 23108, 79198]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [114625, 20388, 115927, 23112]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  45 ( 3 )
# [ 275, 4396,    7, 4438]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [41125,  276, 41587,   37]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  67,    8,  277, 79198]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [114625,   97, 115927,  278]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  46 ( 4 )
# [ 275,  276,    7,    7]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  37,  276,  277,   37]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  67,   67,  277,  278]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 275,   97,   97,  278]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  47 ( 5 )
# [   7,    7,  277,  278]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 275,   37,   37,  278]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 275,  276,   67,   67]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  97,  276,  277,   97]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  48 ( 6 )
# [1925, 1932, 1939, 1946]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [10175, 10212, 10249, 10286]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [18425, 18492, 18559, 18626]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [26675, 26772, 26869, 26966]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  49 ( 7 )
# [6300, 6328, 6356, 6384]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [51300, 51568, 51836, 52104]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [96300, 96808, 97316, 97824]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [141300, 142048, 142796, 143544]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  50 ( 8 )
# [23200, 6328, 20032, 6384]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [51300, 23204, 51836, 20152]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20272,    3, 23208, 97824]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [141300, 20392, 142796, 23212]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  51 ( 3 )
# [ 300, 6328,    8, 6384]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [51300,  301, 51836,   38]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  68,    9,  302, 97824]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [141300,   98, 142796,  303]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  52 ( 4 )
# [ 300,  301,    8,    8]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  38,  301,  302,   38]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  68,   68,  302,  303]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 300,   98,   98,  303]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  53 ( 5 )
# [   8,    8,  302,  303]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 300,   38,   38,  303]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 300,  301,   68,   68]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  98,  301,  302,   98]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  54 ( 6 )
# [2400, 2408, 2416, 2424]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [11400, 11438, 11476, 11514]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [20400, 20468, 20536, 20604]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [29400, 29498, 29596, 29694]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  55 ( 7 )
# [8700, 8736, 8772, 8808]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [62700, 63006, 63312, 63618]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [116700, 117276, 117852, 118428]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [170700, 171546, 172392, 173238]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  56 ( 8 )
# [23300, 8736, 20036, 8808]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [62700, 23304, 63312, 20156]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20276,    3, 23308, 118428]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [170700, 20396, 172392, 23312]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  57 ( 3 )
# [ 325, 8736,    9, 8808]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [62700,  326, 63312,   39]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  69,   10,  327, 118428]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [170700,   99, 172392,  328]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  58 ( 4 )
# [ 325,  326,    9,    9]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  39,  326,  327,   39]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  69,   69,  327,  328]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 325,   99,   99,  328]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  59 ( 5 )
# [   9,    9,  327,  328]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 325,   39,   39,  328]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 325,  326,   69,   69]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [  99,  326,  327,   99]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  60 ( 6 )
# [2925, 2934, 2943, 2952]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [12675, 12714, 12753, 12792]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [22425, 22494, 22563, 22632]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [32175, 32274, 32373, 32472]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  61 ( 7 )
# [11625, 11670, 11715, 11760]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [75375, 75720, 76065, 76410]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [139125, 139770, 140415, 141060]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [202875, 203820, 204765, 205710]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  62 ( 8 )
# [23400, 11670, 20040, 11760]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [75375, 23404, 76065, 20160]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20280,    3, 23408, 141060]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [202875, 20400, 204765, 23412]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  63 ( 3 )
# [ 350, 11670,   10, 11760]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [75375,  351, 76065,   40]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  70,   11,  352, 141060]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [202875,  100, 204765,  353]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  64 ( 4 )
# [ 350,  351,   10,   10]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  40,  351,  352,   40]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  70,   70,  352,  353]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 350,  100,  100,  353]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  65 ( 5 )
# [  10,   10,  352,  353]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 350,   40,   40,  353]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 350,  351,   70,   70]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 100,  351,  352,  100]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  66 ( 6 )
# [3500, 3510, 3520, 3530]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [14000, 14040, 14080, 14120]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [24500, 24570, 24640, 24710]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [35000, 35100, 35200, 35300]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  67 ( 7 )
# [15125, 15180, 15235, 15290]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [89375, 89760, 90145, 90530]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [163625, 164340, 165055, 165770]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [237875, 238920, 239965, 241010]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  68 ( 8 )
# [23500, 15180, 20044, 15290]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [89375, 23504, 90145, 20164]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20284,    3, 23508, 165770]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [237875, 20404, 239965, 23512]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  69 ( 3 )
# [ 375, 15180,   11, 15290]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [89375,  376, 90145,   41]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  71,   12,  377, 165770]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [237875,  101, 239965,  378]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  70 ( 4 )
# [ 375,  376,   11,   11]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  41,  376,  377,   41]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  71,   71,  377,  378]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 375,  101,  101,  378]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  71 ( 5 )
# [  11,   11,  377,  378]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 375,   41,   41,  378]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 375,  376,   71,   71]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 101,  376,  377,  101]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  72 ( 6 )
# [4125, 4136, 4147, 4158]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [15375, 15416, 15457, 15498]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [26625, 26696, 26767, 26838]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [37875, 37976, 38077, 38178]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  73 ( 7 )
# [19250, 19316, 19382, 19448]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [104750, 105176, 105602, 106028]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [190250, 191036, 191822, 192608]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [275750, 276896, 278042, 279188]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  74 ( 8 )
# [23600, 19316, 20048, 19448]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [104750, 23604, 105602, 20168]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20288,    3, 23608, 192608]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [275750, 20408, 278042, 23612]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  75 ( 3 )
# [ 400, 19316,   12, 19448]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [104750,  401, 105602,   42]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  72,   13,  402, 192608]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [275750,  102, 278042,  403]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  76 ( 4 )
# [ 400,  401,   12,   12]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  42,  401,  402,   42]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  72,   72,  402,  403]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 400,  102,  102,  403]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  77 ( 5 )
# [  12,   12,  402,  403]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 400,   42,   42,  403]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 400,  401,   72,   72]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 102,  401,  402,  102]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  78 ( 6 )
# [4800, 4812, 4824, 4836]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [16800, 16842, 16884, 16926]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [28800, 28872, 28944, 29016]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [40800, 40902, 41004, 41106]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  79 ( 7 )
# [24050, 24128, 24206, 24284]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [121550, 122018, 122486, 122954]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [219050, 219908, 220766, 221624]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [316550, 317798, 319046, 320294]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  80 ( 8 )
# [23700, 24128, 20052, 24284]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [121550, 23704, 122486, 20172]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20292,    3, 23708, 221624]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [316550, 20412, 319046, 23712]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  81 ( 3 )
# [ 425, 24128,   13, 24284]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [121550,  426, 122486,   43]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  73,   14,  427, 221624]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [316550,  103, 319046,  428]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  82 ( 4 )
# [ 425,  426,   13,   13]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  43,  426,  427,   43]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  73,   73,  427,  428]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 425,  103,  103,  428]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  83 ( 5 )
# [  13,   13,  427,  428]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 425,   43,   43,  428]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 425,  426,   73,   73]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 103,  426,  427,  103]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  84 ( 6 )
# [5525, 5538, 5551, 5564]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [18275, 18318, 18361, 18404]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [31025, 31098, 31171, 31244]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [43775, 43878, 43981, 44084]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  85 ( 7 )
# [29575, 29666, 29757, 29848]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [139825, 140336, 140847, 141358]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [250075, 251006, 251937, 252868]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [360325, 361676, 363027, 364378]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  86 ( 8 )
# [23800, 29666, 20056, 29848]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [139825, 23804, 140847, 20176]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20296,    3, 23808, 252868]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [360325, 20416, 363027, 23812]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  87 ( 3 )
# [ 450, 29666,   14, 29848]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [139825,  451, 140847,   44]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  74,   15,  452, 252868]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [360325,  104, 363027,  453]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  88 ( 4 )
# [ 450,  451,   14,   14]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  44,  451,  452,   44]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  74,   74,  452,  453]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 450,  104,  104,  453]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  89 ( 5 )
# [  14,   14,  452,  453]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 450,   44,   44,  453]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 450,  451,   74,   74]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 104,  451,  452,  104]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  90 ( 6 )
# [6300, 6314, 6328, 6342]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [19800, 19844, 19888, 19932]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [33300, 33374, 33448, 33522]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [46800, 46904, 47008, 47112]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  91 ( 7 )
# [35875, 35980, 36085, 36190]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [159625, 160180, 160735, 161290]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [283375, 284380, 285385, 286390]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [407125, 408580, 410035, 411490]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  92 ( 8 )
# [23900, 35980, 20060, 36190]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [159625, 23904, 160735, 20180]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20300,    3, 23908, 286390]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [407125, 20420, 410035, 23912]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  93 ( 3 )
# [ 475, 35980,   15, 36190]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [159625,  476, 160735,   45]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  75,   16,  477, 286390]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [407125,  105, 410035,  478]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  94 ( 4 )
# [ 475,  476,   15,   15]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  45,  476,  477,   45]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  75,   75,  477,  478]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 475,  105,  105,  478]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  95 ( 5 )
# [  15,   15,  477,  478]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 475,   45,   45,  478]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 475,  476,   75,   75]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 105,  476,  477,  105]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  96 ( 6 )
# [7125, 7140, 7155, 7170]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [21375, 21420, 21465, 21510]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [35625, 35700, 35775, 35850]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [49875, 49980, 50085, 50190]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  97 ( 7 )
# [43000, 43120, 43240, 43360]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [181000, 181600, 182200, 182800]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [319000, 320080, 321160, 322240]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [457000, 458560, 460120, 461680]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  98 ( 8 )
# [24000, 43120, 20064, 43360]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [181000, 24004, 182200, 20184]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20304,    3, 24008, 322240]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [457000, 20424, 460120, 24012]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  99 ( 3 )
# [ 500, 43120,   16, 43360]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [181000,  501, 182200,   46]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  76,   17,  502, 322240]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [457000,  106, 460120,  503]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  100 ( 4 )
# [ 500,  501,   16,   16]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  46,  501,  502,   46]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  76,   76,  502,  503]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 500,  106,  106,  503]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  101 ( 5 )
# [  16,   16,  502,  503]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 500,   46,   46,  503]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 500,  501,   76,   76]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 106,  501,  502,  106]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  102 ( 6 )
# [8000, 8016, 8032, 8048]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [23000, 23046, 23092, 23138]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [38000, 38076, 38152, 38228]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [53000, 53106, 53212, 53318]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  103 ( 7 )
# [51000, 51136, 51272, 51408]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [204000, 204646, 205292, 205938]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [357000, 358156, 359312, 360468]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [510000, 511666, 513332, 514998]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  104 ( 8 )
# [24100, 51136, 20068, 51408]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [204000, 24104, 205292, 20188]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20308,    3, 24108, 360468]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [510000, 20428, 513332, 24112]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  105 ( 3 )
# [ 525, 51136,   17, 51408]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [204000,  526, 205292,   47]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  77,   18,  527, 360468]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [510000,  107, 513332,  528]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  106 ( 4 )
# [ 525,  526,   17,   17]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  47,  526,  527,   47]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  77,   77,  527,  528]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 525,  107,  107,  528]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  107 ( 5 )
# [  17,   17,  527,  528]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 525,   47,   47,  528]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 525,  526,   77,   77]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 107,  526,  527,  107]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  108 ( 6 )
# [8925, 8942, 8959, 8976]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [24675, 24722, 24769, 24816]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [40425, 40502, 40579, 40656]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [56175, 56282, 56389, 56496]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  109 ( 7 )
# [59925, 60078, 60231, 60384]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [228675, 229368, 230061, 230754]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [397425, 398658, 399891, 401124]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [566175, 567948, 569721, 571494]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  110 ( 8 )
# [24200, 60078, 20072, 60384]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [228675, 24204, 230061, 20192]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [20312,    3, 24208, 401124]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [566175, 20432, 569721, 24212]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  111 ( 3 )
# [ 550, 60078,   18, 60384]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [228675,  551, 230061,   48]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [  78,   19,  552, 401124]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [566175,  108, 569721,  553]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  112 ( 4 )
# [ 550,  551,   18,   18]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [  48,  551,  552,   48]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [  78,   78,  552,  553]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 550,  108,  108,  553]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  113 ( 5 )
# [  18,   18,  552,  553]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 550,   48,   48,  553]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# ...
# [ 597,  796,  797,  597]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  5980 ( 6 )
# [403065, 403572, 404079, 404586]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [426915, 427452, 427989, 428526]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [450765, 451332, 451899, 452466]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [474615, 475212, 475809, 476406]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  5981 ( 7 )
# [6367410, 6381228, 6395046, 6408864]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [6751710, 6766368, 6781026, 6795684]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [7136010, 7151508, 7167006, 7182504]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [7520310, 7536648, 7552986, 7569324]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  5982 ( 8 )
# [25280, 6381228, 22032, 6408864]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [6751710, 25284, 6781026, 22152]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [22272,    3, 25288, 7182504]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [7520310, 22392, 7552986, 25292]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  5983 ( 3 )
# [ 820, 6381228,  508, 6408864]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [6751710,  821, 6781026,  538]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [ 568,   29,  822, 7182504]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [7520310,  598, 7552986,  823]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  5984 ( 4 )
# [ 820,  821,  508,  508]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [ 538,  821,  822,  538]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [ 568,  568,  822,  823]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 820,  598,  598,  823]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  5985 ( 5 )
# [ 508,  508,  822,  823]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 820,  538,  538,  823]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 820,  821,  568,  568]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 598,  821,  822,  598]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  5986 ( 6 )
# [416560, 417068, 417576, 418084]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [441160, 441698, 442236, 442774]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [465760, 466328, 466896, 467464]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [490360, 490958, 491556, 492154]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  5987 ( 7 )
# [6783970, 6798296, 6812622, 6826948]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [7192870, 7208066, 7223262, 7238458]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [7601770, 7617836, 7633902, 7649968]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [8010670, 8027606, 8044542, 8061478]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  5988 ( 8 )
# [25380, 6798296, 22036, 6826948]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [7192870, 25384, 7223262, 22156]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [22276,    3, 25388, 7649968]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [8010670, 22396, 8044542, 25392]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  5989 ( 3 )
# [ 845, 6798296,  509, 6826948]    [LWI R0  R2, NOP , LWI R0  R2, NOP ]
# [7192870,  846, 7223262,  539]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# [ 569,   30,  847, 7649968]    [LWI R0  R2, SADD R1  R1  1, LWI R0  R2, NOP ]
# [8010670,  599, 8044542,  848]    [NOP , LWI R0  R2, NOP , LWI R0  R2]
# -------
# Instr =  5990 ( 4 )
# [ 845,  846,  509,  509]    [NOP , SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL]
# [ 539,  846,  847,  539]    [SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB, NOP ]
# [ 569,  569,  847,  848]    [NOP , SADD R0  ZERO  RCL, NOP , SADD R0  ZERO  RCB]
# [ 845,  599,  599,  848]    [SADD R0  ZERO  RCB, NOP , SADD R0  ZERO  RCL, NOP ]
# -------
# Instr =  5991 ( 5 )
# [ 509,  509,  847,  848]    [SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT]
# [ 845,  539,  539,  848]    [SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB]
# [ 845,  846,  569,  569]    [SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL, SADD ROUT  ZERO  RCR]
# [ 599,  846,  847,  599]    [SADD ROUT  ZERO  RCR, SADD ROUT  ZERO  RCB, SADD ROUT  ZERO  RCT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  5992 ( 6 )
# [430105, 430614, 431123, 431632]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [455455, 455994, 456533, 457072]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [480805, 481374, 481943, 482512]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# [506155, 506754, 507353, 507952]    [SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT, SMUL ROUT  R0  ROUT]
# -------
# Instr =  5993 ( 7 )
# [7214075, 7228910, 7243745, 7258580]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [7648325, 7664060, 7679795, 7695530]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [8082575, 8099210, 8115845, 8132480]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# [8516825, 8534360, 8551895, 8569430]    [SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT, SADD R3  R3  ROUT]
# -------
# Instr =  5994 ( 8 )
# [25480, 7228910, 22040, 7258580]    [SSUB R2  R2  R1, NOP , SADD R2  R2  4, NOP ]
# [7648325, 25484, 7679795, 22160]    [NOP , SSUB R2  R2  R1, NOP , SADD R2  R2  4]
# [22280,    3, 25488, 8132480]    [SADD R2  R2  4, BNE R1  R2  3, SSUB R2  R2  R1, NOP ]
# [8516825, 22400, 8551895, 25492]    [NOP , SADD R2  R2  4, NOP , SSUB R2  R2  R1]
# -------
# Instr =  5995 ( 9 )
# [25480, 27084, 22040, 7258580]    [NOP , SADD ROUT  ZERO  R2, NOP , NOP ]
# [   6, 25484, 27188, 22160]    [SADD R1  R1  1, NOP , SADD ROUT  ZERO  R2, NOP ]
# [22280,    3, 25488, 27292]    [NOP , NOP , NOP , SADD ROUT  ZERO  R2]
# [27380, 22400, 8551895, 25492]    [SADD ROUT  ZERO  R2, NOP , NOP , NOP ]
# -------
# Instr =  5996 ( 10 )
# [27080, 27084, 27088, 7258580]    [SADD ROUT  RCR  -4, NOP , SADD ROUT  RCL  4, NOP ]
# [   6, 27184, 27188, 27192]    [NOP , SADD ROUT  RCR  -4, NOP , SADD ROUT  RCL  4]
# [27280,    3, 27288, 27292]    [SADD ROUT  RCL  -12, NOP , SADD ROUT  RCR  -4, NOP ]
# [27380, 27384, 8551895, 27392]    [NOP , SADD ROUT  RCL  4, NOP , SADD ROUT  RCR  12]
# -------
# Instr =  5997 ( 11 )
# [27080, 27084, 27088, 27092]    [NOP , NOP , NOP , SADD ROUT  RCL  4]
# [27180, 27184, 27188, 27192]    [SADD ROUT  RCR  -4, NOP , NOP , NOP ]
# [27280, 27284, 27288, 27292]    [NOP , SADD ROUT  RCR  -4, NOP , NOP ]
# [27380, 27384, 27388, 27392]    [NOP , NOP , SADD ROUT  RCR  -4, NOP ]
# -------
# Instr =  5998 ( 12 )
# [ 620,  621,  622,  623]    [LWI R0  ROUT, LWI R0  ROUT, LWI R0  ROUT, LWI R0  ROUT]
# [ 645,  646,  647,  648]    [LWI R0  ROUT, LWI R0  ROUT, LWI R0  ROUT, LWI R0  ROUT]
# [ 670,  671,  672,  673]    [LWI R0  ROUT, LWI R0  ROUT, LWI R0  ROUT, LWI R0  ROUT]
# [ 695,  696,  697,  698]    [LWI R0  ROUT, LWI R0  ROUT, LWI R0  ROUT, LWI R0  ROUT]
# -------
# Instr =  5999 ( 13 )
# [ 620,  621,  125,  623]    [NOP , NOP , SADD ROUT  R1  ZERO, NOP ]
# [ 645,  646,  647,  125]    [NOP , NOP , NOP , SADD ROUT  R1  ZERO]
# [  14,  671,  672,  673]    [SADD ROUT  R1  ZERO, NOP , NOP , NOP ]
# [ 695,   14,  697,  698]    [NOP , SADD ROUT  R1  ZERO, NOP , NOP ]
# -------
# Instr =  6000 ( 14 )
# [ 620,  125, 905468125,  125]    [NOP , SADD ROUT  ZERO  RCR, SMUL R3  R3  ROUT, SADD ROUT  ZERO  RCB]
# [  14,  646,  125, 961941250]    [SADD ROUT  ZERO  RCB, NOP , SADD ROUT  ZERO  RCR, SMUL R3  R3  ROUT]
# [9380,   14,  672,  125]    [SMUL R0  R0  ROUT, SADD ROUT  ZERO  RCB, NOP , SADD ROUT  ZERO  RCT]
# [  14, 9744,   14,  698]    [SADD ROUT  ZERO  RCR, SMUL R0  R0  ROUT, SADD ROUT  ZERO  RCL, NOP ]
# -------
# Instr =  6001 ( 15 )
# [ 125, 903613750, 905468125, 907322500]    [SADD ROUT  ZERO  RCR, SMUL R3  R3  ROUT, NOP , SMUL R3  R3  ROUT]
# [9030,  125, 959974375, 961941250]    [SMUL R0  R0  ROUT, SADD ROUT  ZERO  RCR, SMUL R3  R3  ROUT, NOP ]
# [9380, 9394,   14, 1016560000]    [NOP , SMUL R0  R0  ROUT, SADD ROUT  ZERO  RCL, SMUL R3  R3  ROUT]
# [9730, 9744, 9758,   14]    [SMUL R0  R0  ROUT, NOP , SMUL R0  R0  ROUT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  6002 ( 16 )
# [901759375, 903613750, 905468125,   14]    [SMUL R3  R3  ROUT, NOP , NOP , SADD ROUT  ZERO  RCT]
# [ 125, 958007500,   14, 961941250]    [SADD ROUT  ZERO  RCR, SMUL R3  R3  ROUT, SADD ROUT  ZERO  RCB, NOP ]
# [9380,  125, 9408,   14]    [NOP , SADD ROUT  ZERO  RCT, SMUL R0  R0  ROUT, SADD ROUT  ZERO  RCB]
# [ 125, 9744, 9758, 9772]    [SADD ROUT  ZERO  RCB, NOP , NOP , SMUL R0  R0  ROUT]
# -------
# Instr =  6003 ( 17 )
# [901759375, 903613750,   14, 8722]    [NOP , NOP , SADD ROUT  ZERO  RCR, SMUL R0  R0  ROUT]
# [956040625,   14, 9058,   14]    [SMUL R3  R3  ROUT, SADD ROUT  ZERO  RCR, SMUL R0  R0  ROUT, SADD ROUT  ZERO  RCL]
# [ 125, 1012401250,  125, 9422]    [SADD ROUT  ZERO  RCB, SMUL R3  R3  ROUT, SADD ROUT  ZERO  RCL, SMUL R0  R0  ROUT]
# [1064603125,  125, 9758, 9772]    [SMUL R3  R3  ROUT, SADD ROUT  ZERO  RCL, NOP , NOP ]
# -------
# Instr =  6004 ( 18 )
# [901759375,   14, 8708, 907331222]    [NOP , SADD ROUT  ZERO  RCR, SMUL R0  R0  ROUT, SADD R3  R3  R0]
# [956049655, 9044, 959983433, 9072]    [SADD R3  R3  R0, SMUL R0  R0  ROUT, SADD R3  R3  R0, SMUL R0  R0  ROUT]
# [1010321875, 1012410644, 1014480625, 1016569422]    [SMUL R3  R3  ROUT, SADD R3  R3  R0, SMUL R3  R3  ROUT, SADD R3  R3  R0]
# [1064612855, 1066795000,  125, 9772]    [SADD R3  R3  R0, SMUL R3  R3  ROUT, SADD ROUT  ZERO  RCL, NOP ]
# -------
# Instr =  6005 ( 19 )
# [  14, 8694, 905476833, 907331222]    [SADD ROUT  ZERO  RCR, SMUL R0  R0  ROUT, SADD R3  R3  R0, NOP ]
# [956049655, 958016544, 959983433, 961950322]    [NOP , SADD R3  R3  R0, NOP , SADD R3  R3  R0]
# [1010331255, 1012410644, 1014490033, 1016569422]    [SADD R3  R3  R0, NOP , SADD R3  R3  R0, NOP ]
# [1064612855, 1066804744, 1068986875,  125]    [NOP , SADD R3  R3  R0, SMUL R3  R3  ROUT, SADD ROUT  ZERO  RCL]
# -------
# Instr =  6006 ( 20 )
# [8680, 903622444, 905476833, 907331222]    [SMUL R0  R0  ROUT, SADD R3  R3  R0, NOP , NOP ]
# [956049655, 958016544, 959983433, 961950322]    [NOP , NOP , NOP , NOP ]
# [1010331255, 1012410644, 1014490033, 1016569422]    [NOP , NOP , NOP , NOP ]
# [1064612855, 1066804744, 1068996633, 1071178750]    [NOP , NOP , SADD R3  R3  R0, SMUL R3  R3  ROUT]
# -------
# Instr =  6007 ( 21 )
# [901768055, 27084, 905476833, 907331222]    [SADD R3  R3  R0, SADD ROUT  ZERO  R2, NOP , NOP ]
# [956049655, 958016544, 27188, 961950322]    [NOP , NOP , SADD ROUT  ZERO  R2, NOP ]
# [1010331255, 1012410644, 1014490033, 27292]    [NOP , NOP , NOP , SADD ROUT  ZERO  R2]
# [27380, 1066804744, 1068996633, 1071188522]    [SADD ROUT  ZERO  R2, NOP , NOP , SADD R3  R3  R0]
# -------
# Instr =  6008 ( 22 )
# [27080, 27100, 27088, 907331222]    [SADD ROUT  RCR  -4, SADD R2  R2  16, SADD ROUT  RCL  4, NOP ]
# [956049655, 27184, 27204, 27192]    [NOP , SADD ROUT  RCR  -4, SADD R2  R2  16, SADD ROUT  RCL  4]
# [27280, 1012410644, 27288, 27308]    [SADD ROUT  RCL  -12, NOP , SADD ROUT  RCR  -4, SADD R2  R2  16]
# [27396, 27384, 1068996633, 27392]    [SADD R2  R2  16, SADD ROUT  RCL  4, NOP , SADD ROUT  RCR  12]
# -------
# Instr =  6009 ( 23 )
# [27080, 27084, 27088, 27092]    [NOP , SADD ROUT  R2  -16, NOP , SADD ROUT  RCL  4]
# [27180, 27184, 27188, 27192]    [SADD ROUT  RCR  -4, NOP , SADD ROUT  R2  -16, NOP ]
# [27280, 27284, 27288, 27292]    [NOP , SADD ROUT  RCR  -4, NOP , SADD ROUT  R2  -16]
# [27380, 27384, 27388, 27392]    [SADD ROUT  R2  -16, NOP , SADD ROUT  RCR  -4, NOP ]
# -------
# Instr =  6010 ( 24 )
# [27080, 27084, 27088, 27092]    [SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT ]
# [27180, 27184, 27188, 27192]    [SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT]
# [27280, 27284, 27288, 27292]    [SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT]
# [27380, 27384, 27388, 27392]    [SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT, SWI R3  ROUT ]
# -------
# Instr =  6011 ( 25 )
# [25496,   30, 27088, 27092]    [SADD R2  R2  16, SADD ROUT  ZERO  R1, NOP , NOP ]
# [27180, 25500,   30, 27192]    [NOP , SADD R2  R2  16, SADD ROUT  ZERO  R1, NOP ]
# [27280, 27284, 25504,   30]    [NOP , NOP , SADD R2  R2  16, SADD ROUT  ZERO  R1]
# [  30, 27384, 27388, 25508]    [SADD ROUT  ZERO  R1, NOP , NOP , SADD R2  R2  16]
# -------
# Instr =  6012 ( 26 )
# [-3000,   30, -120, 27092]    [SMUL ROUT  RCR  R1, NOP , SMUL ROUT  RCL  -4, NOP ]
# [27180, -3000,   30, -120]    [NOP , SMUL ROUT  RCR  R1, NOP , SMUL ROUT  RCL  -4]
# [-120,    0, -3000,   30]    [SMUL ROUT  RCL  -4, SADD R1  ZERO  ZERO, SMUL ROUT  RCR  R1, NOP ]
# [  30, -120, 27388, -3000]    [NOP , SMUL ROUT  RCL  -4, NOP , SMUL ROUT  RCR  R1]
# -------
# Instr =  6013 ( 27 )
# [22496,   30, 21920, 27092]    [SADD R2  R2  ROUT, NOP , SADD R2  R2  ROUT, NOP ]
# [   2, 22500,   30, 22040]    [BNE R1  R2  2, SADD R2  R2  ROUT, NOP , SADD R2  R2  ROUT]
# [22160,    0, 22504,   30]    [SADD R2  R2  ROUT, NOP , SADD R2  R2  ROUT, NOP ]
# [  30, 22280, 27388, 22508]    [NOP , SADD R2  R2  ROUT, NOP , SADD R2  R2  ROUT]
# -------
# Instr =  6014 ( 28 )
# [ 400,  480, 21920,    5]    [SMUL ROUT  R1  -4, SMUL ROUT  R1  16, NOP , SADD R1  R1  1]
# [ -96,  400,  480, 22040]    [SMUL ROUT  R2  -16, SMUL ROUT  R1  -4, SMUL ROUT  R1  16, NOP ]
# [22160,    0,  400,  480]    [NOP , NOP , SMUL ROUT  R1  -4, SMUL ROUT  R1  16]
# [ 480, 22280,  -96,  400]    [SMUL ROUT  R1  16, NOP , SMUL ROUT  R2  -16, SMUL ROUT  R1  -4]
# -------
# Instr =  6015 ( 29 )
# [ -96, 27500, 22400,    5]    [SADD ROUT  ZERO  RCB, SADD R2  R2  RCL, SADD R2  R2  RCL, NOP ]
# [   0,  -96, 27604, 22520]    [SADD R1  ZERO  ZERO, SADD ROUT  ZERO  RCL, SADD R2  R2  RCL, SADD R2  R2  RCL]
# [22640,    0,  -96, 27708]    [SADD R2  R2  RCL, NOP , SADD ROUT  ZERO  RCB, SADD R2  R2  RCL]
# [27796, 22760,  -96,  -96]    [SADD R2  R2  RCL, SADD R2  R2  RCL, NOP , SADD ROUT  ZERO  RCL]
# -------
# Instr =  6016 ( 30 )
# [22400, 27404, 22400,    2]    [SADD R2  R2  ROUT, SADD R2  R2  RCL, NOP , BNE R1  R2  2]
# [   0, 22404, 27508, 22520]    [NOP , SADD R2  R2  ROUT, SADD R2  R2  RCL, NOP ]
# [22640,    0, 22408, 27612]    [NOP , NOP , SADD R2  R2  ROUT, SADD R2  R2  RCL]
# [27700, 22760,  -96, 22412]    [SADD R2  R2  RCL, NOP , NOP , SADD R2  R2  ROUT]
# -------
# Instr =  6017 ( 31 )
# [22400, 27404, 22400,    2]    [EXIT, NOP , NOP , NOP ]
# [   0, 22404, 27508, 22520]    [NOP , NOP , NOP , NOP ]
# [22640,    0, 22408, 27612]    [NOP , NOP , NOP , NOP ]
# [27700, 22760,  -96, 22412]    [NOP , NOP , NOP , NOP ]
#
#
# END

# %%
# Get result from CGRA
first_addr_C = first_addr + rowsA*colsA*4 + colsA*colsB*4
result = getResult(first_addr_C, first_addr_C + rowsA*colsB*4, rowsA, colsB)
# Process estra rows/cols
if rowsA%4 != 0:
    for rA in range(rowsA - rowsA%4, rowsA):
        for cB in range(colsB):
            sum = 0
            for k in range(colsA):
                sum += A_data[rA*colsA+k]*B_data[k*colsB+cB]
            result[rA*colsB+cB] = alpha * sum + beta * C_data_cpy[rA*colsB+cB]
if colsB%4 != 0:
    for cB in range(colsB - colsB%4, colsB):
        for rA in range(rowsA - rowsA%4):
            sum = 0
            for k in range(colsA):
                sum += A_data[rA*colsA+k]*B_data[k*colsB+cB]
            result[rA*colsB+cB] = alpha * sum + beta * C_data_cpy[rA*colsB+cB]

# Get cpu output
expected_res = gemm_cpu(A_data_cpy, B_data_cpy, C_data_cpy, rowsA, colsA, colsB, alpha, beta)

# Check result correctness
errors = 0
for i in range(len(expected_res)):
    if expected_res[i] != result[i]:
        errors += 1
if errors > 0:
    print("Err: " + str(errors))
    print("Expected: ")
    printAsMatrix(expected_res, rowsA, colsB)
    print("CGRA: ")
    printAsMatrix(result, rowsA, colsB)
else:
    print("OK")
# Out:
# OK
